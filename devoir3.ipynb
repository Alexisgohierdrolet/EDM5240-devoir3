# %% [markdown]
# # User : Alexis Gohier-Drolet
# # Utilisation des données pour un cours d'informatique

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
pd.set_option("display.float_format", lambda x : "%.2f" % x)

# %%
info = pd.read_csv("ati.csv")

# %%
info.dtypes
# Out:
# year                int64
# month               int64
# request_number     object
# summary_en         object
# summary_fr         object
# disposition        object
# pages               int64
# owner_org          object
# owner_org_title    object
# dtype: object

# %%
info
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2017      5   A-2016-00059
# 2      2016      3   A-2015-00059
# 3      2016      7   A-2016-00076
# 4      2016      3   A-2015-00113
# 5      2016      3   A-2015-00109
# 6      2016      3   A-2015-00108
# 7      2016      3   A-2015-00107
# 8      2016      3   A-2015-00082
# 9      2016      3   A-2015-00106
# 10     2016      3   A-2015-00100
# 11     2016      3   A-2015-00098
# 12     2016      3   A-2015-00085
# 13     2016      3   A-2015-00084
# 14     2016      3   A-2015-00063
# 15     2016      3   A-2015-00061
# 16     2016      3   A-2015-00058
# 17     2016      3   A-2015-00057
# 18     2016      3   A-2015-00052
# 19     2016      3   A-2014-00183
# 20     2016      3   A-2014-00182
# 21     2016      3   A-2014-00161
# 22     2016      3   A-2014-00160
# 23     2016      7   A-2016-00071
# 24     2017      7   A-2017-00063
# 25     2016     10   A-2016-00121
# ...

# %% [markdown]
# Les deux commandes précédentes servent principalement à visualiser les données, savoir l'affichage, le type de données et le nom de chacune des colonnes. Plus facile pour extraire de l'information pertinente.

# %%
info.owner_org_title.value_counts().head(25)
# Out:
# Global Affairs Canada | Affaires mondiales Canada                                                                1799
# National Defence | Défense nationale                                                                             1703
# Employment and Social Development Canada | Emploi et Développement social Canada                                 1538
# Innovation, Science and Economic Development Canada | Innovation, Sciences et Développement économique Canada    1395
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                       1394
# Privy Council Office | Bureau du Conseil privé                                                                   1233
# Natural Resources Canada | Ressources naturelles Canada                                                          1187
# Department of Finance Canada | Ministère des Finances Canada                                                     1181
# ...

# %% [markdown]
# Ici, après avoir essayé de comprendre comment le document était structuré, j'ai voulu connaître les 25 départements qui ont reçu le plus de demandes d'accès à l'information. Je suis allé voir sur OpenRefine si il y avait des doublons, mais je n'en ai pas trouvé. Cela semble bien classé. Près de 1800 demandes ont été faites à Affaire mondiales Canada.

# %%
info.disposition.value_counts()
# Out:
# Disclosed in part / Communication partielle                                                                                                                                                                                                                                                                                                9336
# All disclosed / Communication totale                                                                                                                                                                                                                                                                                                       2740
# ...

# %%
tot = info.disposition.str.contains("All di", na=False)
info[tot]
# Out:
#        year  month   request_number  \
# 35     2016      5     A-2016-00011
# 44     2016      5     A-2016-00003
# 95     2016      8     A-2016-00093
# 108    2016      9     A-2016-00102
# 114    2016     10     A-2016-00103
# 116    2016     10     A-2016-00108
# 117    2016     10     A-2016-00109
# 118    2016     10     A-2016-00111
# 119    2016     10     A-2016-00113
# 126    2016     10     A-2016-00122
# 127    2016     10     A-2016-00124
# 131    2016     11     A-2016-00123
# 132    2016     11    A-2016-000125
# 135    2016     11     A-2016-00128
# 140    2016     11     A-2016-00140
# 142    2017      1     A-2016-00163
# 143    2017      1     A-2016-00162
# 144    2017      1     A-2016-00161
# 161    2017      2     A-2016-00167
# 163    2017      2     A-2016-00134
# 164    2017      3     A-2016-00175
# 201    2017      3     A-2016-00193
# 203    2017      3     A-2016-00191
# 206    2017      3     A-2016-00183
# 207    2017      3     A-2016-00154
# ...

# %%
tot2 = info.disposition.str.contains("All Di", na=False)
info[tot2]
# Out:
#        year  month    request_number  \
# 85     2016      7      A-2014-00190
# 2793   2016      3  106-3-2015-00033
# 2805   2016      8      A-2016-00016
# 2819   2017      7      A-2017-00009
# 2820   2017      7      A-2017-00010
# 2821   2017      7      A-2017-00016
# 2822   2017      8      A-2017-00015
# 4309   2016     10     11452-019-152
# 4310   2016     10     11452-019-153
# 4700   2016      5          A-081100
# 4701   2017      9     A-2017-095428
# 4702   2017      9     A-2017-095534
# 4704   2016      4          A-084533
# 4705   2016      6          A-084344
# 4714   2017      9     A-2017-095540
# 4715   2016      7          A-086444
# 4719   2016      9          A-070153
# 4721   2016      9          A-087497
# 4723   2016      4          A-084034
# 4798   2016      4          A-079229
# 4799   2016      4          A-080066
# 4800   2016      4          A-082035
# 4801   2016      4          A-082848
# 4803   2016      4          A-082990
# ...

# %%
info[tot | tot2]
# Out:
#        year  month   request_number  \
# 35     2016      5     A-2016-00011
# 44     2016      5     A-2016-00003
# 85     2016      7     A-2014-00190
# 95     2016      8     A-2016-00093
# 108    2016      9     A-2016-00102
# 114    2016     10     A-2016-00103
# 116    2016     10     A-2016-00108
# 117    2016     10     A-2016-00109
# 118    2016     10     A-2016-00111
# 119    2016     10     A-2016-00113
# 126    2016     10     A-2016-00122
# 127    2016     10     A-2016-00124
# 131    2016     11     A-2016-00123
# 132    2016     11    A-2016-000125
# 135    2016     11     A-2016-00128
# 140    2016     11     A-2016-00140
# 142    2017      1     A-2016-00163
# 143    2017      1     A-2016-00162
# 144    2017      1     A-2016-00161
# 161    2017      2     A-2016-00167
# 163    2017      2     A-2016-00134
# 164    2017      3     A-2016-00175
# 201    2017      3     A-2016-00193
# 203    2017      3     A-2016-00191
# 206    2017      3     A-2016-00183
# ...

# %% [markdown]
# Ici, je cherchais le nombre de demandes qui ont reçu la documentation complète. Il y avait plusieurs notations différentes selon le value_counts dans la colonne "disposition". Le point en commun était les lettres "All Di" ou "All di" pour "All Disclosed". J'ai donc cherché selon ces deux critères, et je les ai mis ensemble dans la liste. 5911 demandes ont reçu la documentation complète sur 28295.

# %%
annee = info.year == 2016

# %%
info[annee]
# Out:
#        year  month   request_number  \
# 0      2016      3     A-2015-00070
# 2      2016      3     A-2015-00059
# 3      2016      7     A-2016-00076
# 4      2016      3     A-2015-00113
# 5      2016      3     A-2015-00109
# 6      2016      3     A-2015-00108
# 7      2016      3     A-2015-00107
# 8      2016      3     A-2015-00082
# 9      2016      3     A-2015-00106
# 10     2016      3     A-2015-00100
# 11     2016      3     A-2015-00098
# 12     2016      3     A-2015-00085
# 13     2016      3     A-2015-00084
# 14     2016      3     A-2015-00063
# 15     2016      3     A-2015-00061
# 16     2016      3     A-2015-00058
# 17     2016      3     A-2015-00057
# 18     2016      3     A-2015-00052
# 19     2016      3     A-2014-00183
# 20     2016      3     A-2014-00182
# 21     2016      3     A-2014-00161
# 22     2016      3     A-2014-00160
# 23     2016      7     A-2016-00071
# 25     2016     10     A-2016-00121
# 26     2016      4      A-2016-0002
# ...

# %%
info[annee].month.value_counts(ascending=False)
# Out:
# 12    1509
# 10    1416
# 6     1409
# 9     1399
# 11    1389
# 5     1342
# 7     1264
# 3     1255
# 8     1220
# 4     1070
# 55       1
# 13       1
# Name: month, dtype: int64

# %%
annee2 = info[annee].month <= 12

# %%
info[annee][annee2].month.hist(bins=10)

# %% [markdown]
# J'ai voulu savoir combien de demandes par mois ont été faites en 2016. J'ai créé une variable qui inclut toutes les rangées avec l'année 2016. Ensuite, j'ai vérifié les mois associés. Il n'y avait pas de mois 1 et 2, donc la récolte a probablement commencé en mars. Il y avait aussi deux données aberrantes, car le mois était supérieur à 13. J'ai créé une seconde variable pour éliminer ces données. J'ai afficher un histogramme avec 10 barres (12 mois moins janvier et février).
